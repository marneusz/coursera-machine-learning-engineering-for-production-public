# %% [markdown]
# # Ungraded Lab Part 1 - Deploying a Machine Learning Model
#
# Welcome to this ungraded lab! If you are reading this it means you did the setup properly, nice work!
#
# This lab is all about deploying a real machine learning model, and checking what doing so feels like. More concretely, you will deploy a computer vision model trained to detect common objects in pictures. Deploying a model is one of the last steps in a prototypical machine learning lifecycle. However, we thought it would be exciting to get you to deploy a model right away. This lab uses a pretrained model called [`YOLOV3`](https://pjreddie.com/darknet/yolo/). This model is very convenient for two reasons: it runs really fast, and for object detection it yields accurate results.
#
# The sequence of steps/tasks to complete in this lab are as follow:
# 1. Inspect the image data set used for object detection
# 2. Take a look at the model itself
# 3. Deploy the model using [`fastAPI`](https://fastapi.tiangolo.com/)

# %% [markdown]
# ## Object Detection with YOLOV3
#
# ### Inspecting the images
#
# Let's take a look at the images that will be passed to the YOLOV3 model. This will bring insight on what type of common objects are present for detection. These images are part of the [`ImageNet`](http://www.image-net.org/index) dataset.

# %%
from IPython.display import Image, display

# %%
# Some example images
image_files = [
    'apple.jpg',
    'clock.jpg',
    'oranges.jpg',
    'car.jpg'
]

for image_file in image_files:
    print(f"\nDisplaying image: {image_file}")
    display(Image(filename=f"images/{image_file}"))
# Out:
# Displaying image: apple.jpg
# Displaying image: clock.jpg
# Displaying image: oranges.jpg
# Displaying image: car.jpg

# %% [markdown]
# ### Overview of the model
#
# Now that you have a sense of the image data and the objects present, let's try and see if the model is able to detect and classify them correctly.
#
# For this you will be using [`cvlib`](https://www.cvlib.net/), which is a very simple but powerful library for object detection that is fueled by [`OpenCV`](https://docs.opencv.org/4.5.1/) and [`Tensorflow`](https://www.tensorflow.org/).
#
# More concretely, you will use the [`detect_common_objects`](https://docs.cvlib.net/object_detection/) function, which takes an image formatted as a [`numpy array`](https://numpy.org/doc/stable/reference/generated/numpy.array.html) and returns:
#
# - `bbox`: list of list containing bounding box coordinates for detected objects.
#
#         Example:
#
#     ```python
#         [[32, 76, 128, 192], [130, 83, 220, 185]]
#     ```
#
#
# - `label`: list of labels for detected objects.
#
#         Example:
#     ```python
#         ['apple', 'apple']
#     ```
#
#
# - `conf`: list of confidence scores for detected objects.
#         Example:
#
#     ```python
#         [0.6187325716018677, 0.42835739254951477]
#     ```
#
# In the next section you will visually see these elements in action.

# %% [markdown]
# ### Creating the detect_and_draw_box function
#
# Before using the object detection model, create a directory where you can store the resulting images:

# %%
import os

dir_name = "images_with_boxes"
if not os.path.exists(dir_name):
    os.mkdir(dir_name)

# %% [markdown]
# Let's define the `detect_and_draw_box` function which takes as input arguments: the **filename** of a file on your system, a **model**, and a **confidence level**. With these inputs, it detects common objects in the image and saves a new image displaying the bounding boxes alongside the detected object.
#
# You might ask yourself why does this function receive the model as an input argument? What models are there to choose from? The answer is that `detect_common_objects` uses the `yolov3` model by default.  However, there is another option available that is much tinier and requires less computational power.
#
# It is the `yolov3-tiny` version. As the model name indicates, this model is designed for constrained environments that cannot store big models. With this comes a natural tradeoff: the results are less accurate than the full model. However, it still works pretty well. Going forward, we recommend you stick to it since it is a lot smaller than the regular `yolov3` and downloading its pretrained weights takes less time.
#
# The model output is a vector of probabilities for the presence of different objects on the image. The last input argument, confidence level, determines the threshold that the probability needs to surpass to report that a given object is detected on the supplied image. By default, `detect_common_objects` uses a value of 0.5 for this.

# %%
import cv2
import cvlib as cv
from cvlib.object_detection import draw_bbox


def detect_and_draw_box(filename, model="yolov3", confidence=0.5):
    """Detects common objects on an image and creates a new image with bounding boxes.

    Args:
        filename (str): Filename of the image.
        model (str): Either "yolov3" or "yolov3-tiny". Defaults to "yolov3-tiny".
        confidence (float, optional): Desired confidence level. Defaults to 0.5.
    """
    
    # Images are stored under the images/ directory
    img_filepath = f'images/{filename}'
    
    # Read the image into a numpy array
    img = cv2.imread(img_filepath)
    
    # Perform the object detection
    bbox, label, conf = cv.detect_common_objects(img, confidence=confidence, model=model)
    
    # Print current image's filename
    print(f"========================\nImage processed: {filename}\n")
    
    # Print detected objects with confidence level
    for l, c in zip(label, conf):
        print(f"Detected object: {l} with confidence level of {c}\n")
    
    # Create a new image that includes the bounding boxes
    output_image = draw_bbox(img, bbox, label, conf)
    
    # Save the image in the directory images_with_boxes
    cv2.imwrite(f'images_with_boxes/{filename}', output_image)
    
    # Display the image with bounding boxes
    display(Image(f'images_with_boxes/{filename}'))

# %% [markdown]
# Let's try it out for the example images.

# %%
for image_file in image_files:
    detect_and_draw_box(image_file)
# Out:
# Downloading yolov3.cfg from https://github.com/arunponnusamy/object-detection-opencv/raw/master/yolov3.cfg
#   0% |                                                                        |
# Downloading yolov3.weights from https://pjreddie.com/media/files/yolov3.weights
#  99% |####################################################################### |
# Downloading yolov3_classes.txt from https://github.com/arunponnusamy/object-detection-opencv/raw/master/yolov3.txt
# 100% |                                                                        |
# ========================
# Image processed: apple.jpg
#
# Detected object: apple with confidence level of 0.6279281973838806
# ========================
# Image processed: clock.jpg
#
# Detected object: clock with confidence level of 0.9929457306861877
#
# Detected object: clock with confidence level of 0.8621425032615662
# ========================
# Image processed: oranges.jpg
#
# Detected object: orange with confidence level of 0.8040305376052856
#
# Detected object: orange with confidence level of 0.7812944650650024
# ========================
# Image processed: car.jpg
#
# Detected object: car with confidence level of 0.968181312084198

# %% [markdown]
# ## Changing the confidence level
#
# Looks like the object detection went fairly well. Let's try it out on a more difficult image containing several objects:

# %%
detect_and_draw_box("fruits.jpg")
# Out:
# ========================
# Image processed: fruits.jpg
#
# Detected object: apple with confidence level of 0.9271863698959351
#
# Detected object: orange with confidence level of 0.8668249845504761
#
# Detected object: dining table with confidence level of 0.7558943033218384
#
# Detected object: orange with confidence level of 0.7322269678115845
#
# Detected object: apple with confidence level of 0.6720700263977051
#
# Detected object: orange with confidence level of 0.641866147518158
#
# Detected object: apple with confidence level of 0.5462460517883301

# %% [markdown]
# The **model failed to detect** several fruits and **misclassified** an orange as an apple. This might seem strange since it was able to detect one apple before, so one might think the model has a fair representation on how an apple looks like.
#
# One possibility is that the model **did** detect the other fruits but with a confidence level lower than 0.5. Let's test if  this is a valid hypothesis:

# %%
detect_and_draw_box("fruits.jpg", confidence=0.2)
# Out:
# ========================
# Image processed: fruits.jpg
#
# Detected object: apple with confidence level of 0.9271863698959351
#
# Detected object: orange with confidence level of 0.8668249845504761
#
# Detected object: dining table with confidence level of 0.7558943033218384
#
# Detected object: orange with confidence level of 0.7322269678115845
#
# Detected object: apple with confidence level of 0.6720700263977051
#
# Detected object: orange with confidence level of 0.641866147518158
#
# Detected object: apple with confidence level of 0.5462460517883301
#
# Detected object: apple with confidence level of 0.4414003789424896
#
# Detected object: orange with confidence level of 0.4134720265865326
#
# Detected object: apple with confidence level of 0.38624802231788635
#
# Detected object: apple with confidence level of 0.37145137786865234
#
# Detected object: apple with confidence level of 0.3274080455303192

# %% [markdown]
# By lowering the confidence level the model successfully detects most of the fruits. However, in order to correctly detect the objects present, we had to  set the confidence level really low. In general, you should be careful when decreasing or increasing these kinds of parameters, as changing them might yield undesired results.
#
# As for this concrete example when an orange was misclassified as an apple, it serves as a reminder that these models are not perfect and this should be considered when using them for tasks in production.

# %% [markdown]
# ## Deploying the model using fastAPI
#
#
# ### Placing your object detection model in a server
#
# Now that you know how the model works it is time for you to deploy it! Aren't you excited? :)
#
# Before diving into deployment, let's quickly recap some important concepts and how they translate to `fastAPI`. Let's also create a directory to store the images that are uploaded to the server.

# %%
dir_name = "images_uploaded"
if not os.path.exists(dir_name):
    os.mkdir(dir_name)

# %% [markdown]
# ### Some concept clarifications
#
# #### Client-Server model
#
# When talking about **deploying**, what is usually meant is to put all of the software required for predicting in a `server`. By doing this, a `client` can interact with the model by sending `requests` to the server.
#
# This client-server interaction is out of the scope of this notebook but there are a lot of resources on the internet that you can use to understand it better.
#
# The important thing you need to focus on, is that the Machine Learning model lives in a server waiting for clients to submit prediction requests. The client should provide the required information that the model needs in order to make a prediction. Keep in mind that it is common to batch many predictions in a single request. The server will use the information provided to return predictions to the client, who can then use them at their leisure.
#
# Let's get started by creating an instance of the `FastAPI` class:
#
# ```python
# app = FastAPI()
# ```
#
# The next step is using this instance to create endpoints that will handle the logic for predicting (more on this next). Once all the code is in place to run the server you only need to use the command:
#
# ```python
# uvicorn.run(app)
# ```
#
# Your API is coded using fastAPI but the serving is done using [`uvicorn`](https://www.uvicorn.org/), which is a really fast Asynchronous Server Gateway Interface (ASGI) implementation. Both technologies are closely interconnected and you don't need to understand the implementation details. Knowing that uvicorn handles the serving is sufficient for the purpose of this lab.
#
# #### Endpoints
#
# You can host multiple Machine Learning models on the same server. For this to work, you can assign a different `endpoint` to each model so you always know what model is being used. An endpoint is represented by a pattern in the `URL`. For example, if you have a website called `myawesomemodel.com` you could have three different models in the following endpoints:
#
# - `myawesomemodel.com/count-cars/`
# - `myawesomemodel.com/count-apples/`
# - `myawesomemodel.com/count-plants/`
#
# Each model would do what the name pattern suggests.
#
# In fastAPI you define an endpoint by creating a function that will handle all of the logic for that endpoint and [decorating](https://www.python.org/dev/peps/pep-0318/) it with a function that contains information on the HTTP method allowed (more on this next) and the pattern in the URL that it will use.
#
# The following example shows how to allow a HTTP GET request for the endpoint "/my-endpoint":
#
# ```python
# @app.get("/my-endpoint")
# def handle_endpoint():
#     ...
#     ...
# ```
#
#
# #### HTTP Requests
#
# The client and the server communicate with each other through a protocol called `HTTP`. The key concept here is that this communication between client and server uses some verbs to denote common actions. Two very common verbs are:
#
# - `GET` -> Retrieves information from the server.
# - `POST` -> Provides information to the server, which it uses to respond.
#
# If your client does a `GET request` to an endpoint of a server you will get some information from this endpoint without the need to provide additional information. In the case of a `POST request` you are explicitly telling the server that you will provide some information for it that must be processed in some way.
#
# Interactions with Machine Learning models living on endpoints are usually done via a `POST request` since you need to provide the information that is required to compute a prediction.
#
# Let's take a look at a POST request:
#
# ```python
# @app.post("/my-other-endpoint")
# def handle_other_endpoint(param1: int, param2: str):
#     ...
#     ...
#
# ```
#
# For POST requests, the handler function contains parameters. In contrast with GET, POST requests expect the client to provide some information to it. In this case we supplied two parameters: an integer and a string.
#
#
# ### Why fastAPI?
#
# With fastAPI you can create web servers to host your models very easily. Additionally, this platform is extremely fast and it **has a built-in client that can be used to interact with the server**. To use it you will need to visit the "/docs" endpoint, for this case this means to visit http://localhost:8000/docs. Isn't that convenient?
#
# Enough chatter, let's get going!

# %%
import io
import uvicorn
import numpy as np
import nest_asyncio
from enum import Enum
from fastapi import FastAPI, UploadFile, File, HTTPException
from fastapi.responses import StreamingResponse

# %%
# Assign an instance of the FastAPI class to the variable "app".
# You will interact with your api using this instance.
app = FastAPI(title='Deploying a ML Model with FastAPI')

# List available models using Enum for convenience. This is useful when the options are pre-defined.
class Model(str, Enum):
    yolov3tiny = "yolov3-tiny"
    yolov3 = "yolov3"


# By using @app.get("/") you are allowing the GET method to work for the / endpoint.
@app.get("/")
def home():
    return "Congratulations! Your API is working as expected. Now head over to http://localhost:8000/docs."


# This endpoint handles all the logic necessary for the object detection to work.
# It requires the desired model and the image in which to perform object detection.
@app.post("/predict") 
def prediction(model: Model, file: UploadFile = File(...), confidence: float = 0.5):

    # 1. VALIDATE INPUT FILE
    filename = file.filename
    fileExtension = filename.split(".")[-1] in ("jpg", "jpeg", "png")
    if not fileExtension:
        raise HTTPException(status_code=415, detail="Unsupported file provided.")
    
    # 2. TRANSFORM RAW IMAGE INTO CV2 image
    
    # Read image as a stream of bytes
    image_stream = io.BytesIO(file.file.read())
    
    # Start the stream from the beginning (position zero)
    image_stream.seek(0)
    
    # Write the stream of bytes into a numpy array
    file_bytes = np.asarray(bytearray(image_stream.read()), dtype=np.uint8)
    
    # Decode the numpy array as an image
    image = cv2.imdecode(file_bytes, cv2.IMREAD_COLOR)
    
    
    # 3. RUN OBJECT DETECTION MODEL
    
    # Run object detection
    bbox, label, conf = cv.detect_common_objects(image, model=model, confidence=confidence)
    
    # Create image that includes bounding boxes and labels
    output_image = draw_bbox(image, bbox, label, conf)
    
    # Save it in a folder within the server
    cv2.imwrite(f'images_uploaded/{filename}', output_image)
    
    
    # 4. STREAM THE RESPONSE BACK TO THE CLIENT
    
    # Open the saved image for reading in binary mode
    file_image = open(f'images_uploaded/{filename}', mode="rb")
    
    # Return the image as a stream specifying media type
    return StreamingResponse(file_image, media_type="image/jpeg")

# %% [markdown]
# By running the following cell you will spin up the server!
#
# This causes the notebook to block (no cells/code can run) until you manually interrupt the kernel. You can do this by clicking on the `Kernel` tab and then on `Interrupt`. You can also enter Jupyter's command mode by pressing the `ESC` key and tapping the `I` key twice.

# %%
# Allows the server to be run in this interactive environment
nest_asyncio.apply()

# Host depends on the setup you selected (docker or virtual env)
host = "0.0.0.0" if os.getenv("DOCKER-SETUP") else "127.0.0.1"

# Spin up the server!    
uvicorn.run(app, host=host, port=8000)
# Out:
# INFO:     Started server process [29]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     172.17.0.1:36798 - "GET /docs HTTP/1.1" 200 OK
# INFO:     172.17.0.1:36798 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40918 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60142 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60158 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60170 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# Downloading yolov3-tiny.cfg from https://github.com/pjreddie/darknet/raw/master/cfg/yolov3-tiny.cfg
# 100% |                                                                        |
# Downloading yolov3-tiny.weights from https://pjreddie.com/media/files/yolov3-tiny.weights
#  87% |##############################################################          |
# INFO:     127.0.0.1:52458 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
#  90% |################################################################        |
# INFO:     127.0.0.1:52472 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
#  93% |###################################################################     |
# INFO:     127.0.0.1:52488 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
#  99% |####################################################################### |
# INFO:     172.17.0.1:44458 - "POST /predict?model=yolov3-tiny&confidence=0.25 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51466 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51482 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51492 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51502 - "POST /predict?model=yolov3 HTTP/1.1" 200 OK
# INFO:     172.17.0.1:38188 - "POST /predict?model=yolov3-tiny&confidence=0.9999 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55776 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50800 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50808 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50812 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44800 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44806 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44814 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44822 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44824 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44828 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44840 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44842 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44856 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44858 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44860 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44876 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44892 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44898 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44906 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44912 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44922 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44936 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44946 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44960 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44972 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44978 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44994 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45010 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45022 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45038 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53090 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53092 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53106 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53120 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53134 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53142 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53152 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53164 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53172 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53188 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53192 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53194 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53210 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53216 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53232 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53240 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53248 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53264 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53270 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53274 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53276 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53288 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53294 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53300 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53314 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53324 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53338 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53342 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53348 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53352 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53358 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53372 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53382 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53398 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53412 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53420 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53430 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53436 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53444 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53454 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53456 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53464 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53472 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34180 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34194 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34204 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34210 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34216 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34232 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34242 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34246 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34260 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34270 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34272 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34284 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34290 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34292 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34306 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34312 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34322 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34324 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34330 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34342 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34354 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34368 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34372 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34388 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34404 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34412 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34414 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34426 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34428 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34436 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34446 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34456 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34464 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34470 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34478 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34492 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34508 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34510 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34512 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34520 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:34532 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35510 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35524 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35532 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35536 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35552 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35554 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35566 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35568 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35576 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35586 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35590 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35598 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35610 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35622 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35634 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35638 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35644 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35652 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35666 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35678 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35682 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35696 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35708 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35714 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35724 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35736 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35740 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35750 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35764 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35772 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35780 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35796 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35804 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35806 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35820 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35822 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35824 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35828 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35836 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35850 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35858 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35866 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51848 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51858 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51874 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51882 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51884 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51886 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51900 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51910 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51920 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51928 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51942 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51956 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51972 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51984 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52000 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52012 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52018 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52026 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52042 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52052 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52056 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52070 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52082 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52092 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52100 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52106 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52110 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52120 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52128 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52140 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52146 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52156 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52170 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52182 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52184 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52192 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52202 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52206 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52216 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52226 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37202 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37204 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37214 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37228 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37236 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37246 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37248 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37258 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37260 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37262 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37278 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37288 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37292 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37306 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37322 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37326 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37342 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37344 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37348 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37364 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37374 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37386 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37392 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37394 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37398 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37414 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37420 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37428 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37432 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37434 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37440 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37448 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37456 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37466 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37474 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37482 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37498 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37504 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48158 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48174 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48178 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48194 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48200 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48214 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48216 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48224 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48234 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48250 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48266 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48272 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48276 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48280 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48292 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48306 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48310 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48324 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48332 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48348 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48360 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48376 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48392 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48400 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48412 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48428 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48432 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48446 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48462 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48474 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48478 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48480 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48482 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48494 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48496 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48504 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48512 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35760 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35774 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35782 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35786 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35800 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35808 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35814 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35826 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35836 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35838 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35848 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35856 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35858 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35872 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35878 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35890 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35894 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35906 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35912 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35918 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35922 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35932 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35940 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35946 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35954 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35956 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35970 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35976 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35978 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35988 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35996 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36012 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36026 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36036 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49168 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49182 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49190 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49200 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49212 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49222 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49234 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49236 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49248 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49258 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49264 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49268 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49284 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49290 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49296 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49302 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49310 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49324 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49326 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49338 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49350 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49370 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49374 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49386 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49394 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49400 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49412 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49414 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49430 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49446 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49454 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49458 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49460 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49468 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41694 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41704 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41712 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41722 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41732 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41740 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41750 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41756 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41766 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41782 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41792 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41808 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41822 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41824 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41830 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41840 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41846 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41850 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41864 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41872 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41888 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41896 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41906 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41914 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41928 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41940 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41952 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41954 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41970 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41980 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41996 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42006 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42022 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42028 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42044 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42046 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42050 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42062 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47328 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47332 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47336 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47350 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47354 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47364 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47376 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47378 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47392 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47398 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47408 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47410 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47418 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47424 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47432 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47440 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47456 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47466 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47468 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47482 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42092 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42096 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42110 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42120 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42122 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42124 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42128 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42140 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42146 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42156 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42166 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42178 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42194 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42210 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42224 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42232 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42236 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42252 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42258 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42274 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42290 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42294 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42310 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47608 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47610 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47626 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47628 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47632 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47642 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47656 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47658 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47670 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47674 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47688 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47704 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47710 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47712 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47724 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47732 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47748 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47758 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47772 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47776 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47782 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47784 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47786 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47798 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47812 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47824 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47840 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47842 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47856 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47864 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47878 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47890 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47906 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47918 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47922 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47932 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47942 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47956 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47968 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47982 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47994 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48008 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40876 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40890 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40900 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40906 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40918 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40924 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40930 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40938 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40948 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40962 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40966 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40968 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40980 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40988 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40990 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41004 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41012 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41028 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41034 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41036 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41044 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41058 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41070 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41078 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41090 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41098 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41114 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41130 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41134 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41140 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41146 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41148 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41154 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41168 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41182 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41190 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41206 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41210 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41218 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41232 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42054 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42066 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42076 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42090 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42104 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42108 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42110 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42124 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42126 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42138 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42152 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42166 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42174 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42184 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42198 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42208 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42234 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42240 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42252 - "POST /predict?model=yolov3&confidence=0.9 HTTP/1.1" 200 OK
# ...
# INFO:     127.0.0.1:56740 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56746 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56758 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56774 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56784 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56788 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56804 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56812 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56816 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56824 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56836 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56848 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56850 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56858 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56864 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60532 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60536 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60542 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60544 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60548 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60554 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60564 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60566 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60580 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60592 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60604 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60606 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60618 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60634 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60638 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60650 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60656 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60668 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60684 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60688 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60694 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60698 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60708 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60712 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60726 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60732 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60742 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60748 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60764 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60768 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60784 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60798 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53370 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53382 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53390 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53406 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53410 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53420 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53428 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53430 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53446 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53458 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53464 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53476 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53480 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53484 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53498 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53504 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53508 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53514 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53516 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53520 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53522 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53538 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53542 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53546 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53556 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53568 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53570 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53574 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53586 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53590 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53600 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54922 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54932 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54934 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54944 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54952 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54962 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54972 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54988 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55002 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55014 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55030 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55046 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55060 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55066 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55070 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55084 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55086 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55092 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55098 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55108 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55116 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55122 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55134 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55144 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55148 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55150 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55156 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55158 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55168 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55182 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55196 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55202 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55210 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55224 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55236 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53988 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53996 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53998 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54014 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54024 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54026 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54028 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54042 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54052 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54064 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54070 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54086 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54102 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54106 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54120 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54126 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54134 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54150 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54160 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54168 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54184 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54186 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54202 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54206 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54222 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54232 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54248 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54258 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54260 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54274 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54276 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54290 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54306 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54314 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54320 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53842 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53844 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53846 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53856 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53858 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53862 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53872 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53884 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53898 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53912 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53918 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53926 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53932 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53948 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53964 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53974 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53984 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53988 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53990 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54004 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54016 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54024 - "POST /predict?model=yolov3-tiny&confidence=0.9 HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [29]

# %% [markdown]
# The server is now running! Head over to [http://localhost:8000/](http://localhost:8000/) to see it in action.
#
# **Try submitting an image** and see how your API is able to detect objects within it and return a new image containing the bounding boxes alongside the labels of the detected objects. **You can do this by  visiting [http://localhost:8000/docs](http://localhost:8000/docs) to open fastAPI's built-in client.**
#
# When doing so you will get a screen that should look like the one below, follow the instructions next:

# %% [markdown]
# Click on top of the `/predict` endpoint and more options will become visible:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To test your server click on the **Try it out** button.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can choose a model from the **model** field (if you select the full YOLO model the server will be stuck until the weights for this model are downloaded) and a **file** which should be the image in which you want the server to detect objects.
#
# **Submit an image** from your local filesystem by clicking the **Choose File** button, then click on the blue **Execute** button to send an HTTP request to the server. After doing so, **scroll down and you will see the response from it**. Pretty cool, right?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Try different images!** You can use the ones we provided with this lab or some of your own. Since the model is using the default confidence level of 0.5 it might not always succeed to detect some objects.
#
# Also, try submitting non-image files and see how the server reacts to it.

# %% [markdown]
# ## Consuming your model from another client
#
# It is awesome that fastAPI allows you to interact with your API through its built-in client. However, you might wonder how you can interact with your API using regular code and not some UI.
#
# To do so, we have also provided a notebook in which you can check how a minimal client in Python looks like. For this, **leave the server running (don't interrupt the kernel or close this window)** and open the `client.ipynb` notebook. To do so you can open the File Browser tab on the sidebar located on the left of the window and double click on `client.ipynb`. If you cannot see a different tab for each file (which is very useful for moving between them) then it is possible you have the "Simple Interface" (aka Single-Document) mode enabled. To disable it you can go to the View tab and do so.
#
# There is also an optional challenge ahead!
